# %% [markdown]
# ## Partie 1 – Series
#
# Une **Series** est la structure de base de pandas : une colonne de données
# à une seule dimension. Chaque valeur possède une étiquette appelée **index**.
# On peut la voir comme une seule colonne d'un tableur, où l'index joue le rôle
# des numéros de ligne.

# %% [markdown]
# ### 1. Créer une Series contenant 4 températures
#
# - **Objectif** : créer une Series à partir d'une liste de valeurs.
# - **Syntaxe** : `pd.Series([valeur1, valeur2, ...])`

# %%
import pandas as pd

temperatures = pd.Series([22.5, 24.1, 19.8, 26.3])
temperatures
# Out:
# 0    22.5
# 1    24.1
# 2    19.8
# 3    26.3
# dtype: float64

# %% [markdown]
# ### 2. Afficher l'index de la Series
#
# - **Objectif** : voir les étiquettes attribuées à chaque valeur.
# - **Syntaxe** : `ma_series.index`

# %%
temperatures.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# ### 3 & 4. Afficher la première et la dernière valeur
#
# - **Objectif** : accéder à une valeur par sa **position**.
# - **Syntaxe** : `ma_series.iloc[position]`
#   - `iloc` = *integer location* = accès par position (0 = première).
#   - La position `-1` désigne toujours le **dernier** élément.

# %%
print("Première valeur :", temperatures.iloc[0])
print("Dernière valeur :", temperatures.iloc[-1])
# Out:
# Première valeur : 22.5
# Dernière valeur : 26.3

# %% [markdown]
# ### 5. Créer une Series de températures indexée par les heures (12h à 15h)
#
# Deux méthodes possibles :
# - **Objectif** : associer à chaque température une étiquette (l'heure de mesure).
# - **Syntaxe 1** (paramètre `index`) : `pd.Series(valeurs, index=liste_etiquettes)`
# - **Syntaxe 2** (dictionnaire) : `pd.Series({etiquette: valeur, ...})`
#   → les **clés** du dictionnaire deviennent automatiquement l'index.

# %%
# Façon 1 : avec le paramètre index
temp_heures_1 = pd.Series([22.5, 24.1, 19.8, 26.3], index=["12h", "13h", "14h", "15h"])
print("Façon 1 :")
print(temp_heures_1)

# Façon 2 : à partir d'un dictionnaire
temp_heures_2 = pd.Series({"12h": 22.5, "13h": 24.1, "14h": 19.8, "15h": 26.3})
print("\nFaçon 2 :")
print(temp_heures_2)
# Out:
# Façon 1 :
# 12h    22.5
# 13h    24.1
# 14h    19.8
# 15h    26.3
# dtype: float64
#
# Façon 2 :
# 12h    22.5
# 13h    24.1
# 14h    19.8
# 15h    26.3
# dtype: float64

# %% [markdown]
# ### 6. Afficher la première et la dernière valeur
#
# - **Objectif** : réutiliser l'accès par position sur la Series indexée par heures.
# - **Syntaxe** : `ma_series.iloc[0]` et `ma_series.iloc[-1]`
#   (On pourrait aussi passer par l'étiquette : `ma_series["12h"]`, `ma_series["15h"]`.)

# %%
print("Première valeur :", temp_heures_1.iloc[0])
print("Dernière valeur :", temp_heures_1.iloc[-1])
# Out:
# Première valeur : 22.5
# Dernière valeur : 26.3

# %% [markdown]
# ## Partie 2 – DataFrame
#
# Un **DataFrame** est un tableau à deux dimensions : plusieurs colonnes nommées
# et des lignes indexées. C'est la structure centrale de pandas, équivalente à
# une feuille de calcul.

# %% [markdown]
# ### 1. Créer et afficher le DataFrame df_test
#
# - **Objectif** : construire un DataFrame à partir d'un dictionnaire.
# - **Syntaxe** : `pd.DataFrame(dictionnaire)`
#   → chaque **clé** du dictionnaire devient un **nom de colonne**,
#     et la **liste** associée devient le **contenu** de la colonne.

# %%
data = {
    "capteur": ["C001", "C002", "C003"],
    "temperature": [24.5, 25.1, 26.3],
    "humidite": [65, 67, 70]
}

df_test = pd.DataFrame(data)
df_test
# Out:
#   capteur  temperature  humidite
# 0    C001         24.5        65
# 1    C002         25.1        67
# 2    C003         26.3        70

# %% [markdown]
# ### 2. Importer le dataset mesures_capteurs.csv dans le DataFrame df
#
# - **Objectif** : charger un fichier CSV pour le transformer en DataFrame.
# - **Syntaxe** : `pd.read_csv("chemin/vers/le/fichier.csv")`
#   → `read_csv` lit un fichier de valeurs séparées par des virgules
#     (CSV = *Comma-Separated Values*) et le convertit en DataFrame.

# %%
df = pd.read_csv("../data/mesures_capteurs.csv")
df
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  humidite  \
# 0       M0413  2026-01-22 04:00:00       C005     B002        25.46     58.06
# 1       M0290  2026-01-17 01:00:00       C002     B001        24.00     79.73
# 2       M0077  2026-01-08 04:00:00       C005     B002        25.82     54.47
# 3       M0079  2026-01-08 06:00:00       C007     B003        28.23     69.39
# 4       M0183  2026-01-12 14:00:00       C003     B001        20.58     53.80
# ..        ...                  ...        ...      ...          ...       ...
# 600     M0072  2026-01-07 23:00:00       C012     B004        23.67     60.28
# 601     M0107  2026-01-09 10:00:00       C011     B004        24.34     61.42
# 602     M0271  2026-01-16 06:00:00       C007     B003        23.73     63.49
# 603     M0436  2026-01-23 03:00:00       C004     B002        24.83     79.77
# 604     M0103  2026-01-09 06:00:00       C007     B003        17.02     52.04
#
#      pression  consommation etat
# ...

# %% [markdown]
# ### 3. Afficher les dimensions de df
#
# - **Objectif** : connaître le nombre de lignes et de colonnes.
# - **Syntaxe** : `df.shape`
#   → renvoie un couple `(nombre_de_lignes, nombre_de_colonnes)`.

# %%
df.shape
# Out:
# (605, 9)

# %% [markdown]
# ## Partie 3 – Exploration
#
# Avant d'analyser un jeu de données, on l'explore pour comprendre sa taille,
# ses colonnes et le type de chaque information. C'est le premier réflexe de
# tout data scientist face à un nouveau fichier.

# %% [markdown]
# ### 1 & 2. Afficher les premières lignes
#
# - **Objectif** : jeter un œil au début du tableau.
# - **Syntaxe** : `df.head()` affiche les 5 premières lignes par défaut ;
#   `df.head(n)` en affiche `n`.

# %%
print("5 premières lignes :")
display(df.head())

print("10 premières lignes :")
display(df.head(10))
# Out:
# 5 premières lignes :
#   id_mesure           date_heure id_capteur batiment  temperature  humidite  \
# 0     M0413  2026-01-22 04:00:00       C005     B002        25.46     58.06
# 1     M0290  2026-01-17 01:00:00       C002     B001        24.00     79.73
# 2     M0077  2026-01-08 04:00:00       C005     B002        25.82     54.47
# 3     M0079  2026-01-08 06:00:00       C007     B003        28.23     69.39
# 4     M0183  2026-01-12 14:00:00       C003     B001        20.58     53.80
#
#    pression  consommation etat
# 0   1008.95        287.28   OK
# 1    993.39        116.20   OK
# 2   1010.32        288.50   OK
# 3   1019.62        136.65   OK
# 4   1016.58        182.62   OK
# 10 premières lignes :
#   id_mesure           date_heure id_capteur batiment  temperature  humidite  \
# 0     M0413  2026-01-22 04:00:00       C005     B002        25.46     58.06
# 1     M0290  2026-01-17 01:00:00       C002     B001        24.00     79.73
# ...

# %% [markdown]
# ### 3. Afficher les dernières lignes
#
# - **Objectif** : regarder la fin du tableau.
# - **Syntaxe** : `df.tail()` affiche les 5 dernières lignes (`tail` = « queue »).

# %% [markdown]
# ### 4 & 5. Afficher le nombre de lignes et de colonnes
#
# - **Objectif** : récupérer séparément le nombre de lignes puis de colonnes.
# - **Syntaxe** : `df.shape` renvoie `(lignes, colonnes)`.
#   On accède à chaque valeur par sa position : `df.shape[0]` (lignes),
#   `df.shape[1]` (colonnes).

# %%
print("Nombre de lignes :", df.shape[0])
print("Nombre de colonnes :", df.shape[1])
# Out:
# Nombre de lignes : 605
# Nombre de colonnes : 9

# %% [markdown]
# ### 6. Afficher les noms des colonnes
#
# - **Objectif** : lister les intitulés de colonnes.
# - **Syntaxe** : `df.columns`

# %%
df.columns
# Out:
# Index(['id_mesure', 'date_heure', 'id_capteur', 'batiment', 'temperature',
#        'humidite', 'pression', 'consommation', 'etat'],
#       dtype='str')

# %% [markdown]
# ### 7. Afficher les informations générales
#
# - **Objectif** : obtenir un résumé technique du tableau : nombre de lignes,
#   nom et type de chaque colonne, et nombre de valeurs non-manquantes.
# - **Syntaxe** : `df.info()`

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 605 entries, 0 to 604
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_mesure     605 non-null    str
#  1   date_heure    605 non-null    str
#  2   id_capteur    605 non-null    str
#  3   batiment      605 non-null    str
#  4   temperature   599 non-null    float64
#  5   humidite      600 non-null    float64
#  6   pression      600 non-null    float64
#  7   consommation  600 non-null    float64
#  8   etat          601 non-null    str
# dtypes: float64(4), str(5)
# memory usage: 42.7 KB

# %% [markdown]
# ### 8. Afficher les statistiques descriptives
#
# - **Objectif** : obtenir d'un coup les statistiques des colonnes numériques
#   (moyenne, min, max, écart-type, quartiles).
# - **Syntaxe** : `df.describe()`

# %%
df.describe()
# Out:
#        temperature   humidite     pression  consommation
# count   599.000000  600.00000   600.000000    600.000000
# mean     24.878314   64.92620  1012.221900    208.675417
# std       4.059576   10.76905    10.599042     72.243567
# min     -18.500000   28.52000   850.000000     18.120000
# 25%      22.570000   58.17250  1006.790000    160.177500
# 50%      24.860000   65.37500  1012.855000    206.150000
# 75%      27.275000   71.61500  1017.827500    254.127500
# max      58.700000  145.00000  1038.430000    875.000000

# %% [markdown]
# ## Partie 4 – Sélection
#
# Sélectionner, c'est extraire une partie du tableau : une colonne, plusieurs
# colonnes, ou un sous-ensemble de lignes. Deux outils clés : `loc` (par étiquette)
# et `iloc` (par position).

# %% [markdown]
# ### 1. Sélectionner la colonne "temperature"
# - **Objectif** : extraire une seule colonne (renvoie une Series).
# - **Syntaxe** : `df["nom_colonne"]`

# %%
df["temperature"]
# Out:
# 0      25.46
# 1      24.00
# 2      25.82
# 3      28.23
# 4      20.58
#        ...
# 600    23.67
# 601    24.34
# 602    23.73
# 603    24.83
# 604    17.02
# Name: temperature, Length: 605, dtype: float64

# %% [markdown]
# ### 2. Sélectionner plusieurs colonnes
# - **Objectif** : extraire plusieurs colonnes (renvoie un DataFrame).
# - **Syntaxe** : `df[["col1", "col2", ...]]` → noter les **doubles crochets**.

# %%
df[["temperature", "humidite", "pression", "consommation"]]
# Out:
#      temperature  humidite  pression  consommation
# 0          25.46     58.06   1008.95        287.28
# 1          24.00     79.73    993.39        116.20
# 2          25.82     54.47   1010.32        288.50
# 3          28.23     69.39   1019.62        136.65
# 4          20.58     53.80   1016.58        182.62
# ..           ...       ...       ...           ...
# 600        23.67     60.28   1015.11        282.36
# 601        24.34     61.42   1019.43        357.43
# 602        23.73     63.49   1016.46        152.79
# 603        24.83     79.77   1017.05        170.97
# 604        17.02     52.04   1001.14         44.99
#
# [605 rows x 4 columns]

# %% [markdown]
# ### 3. Les 5 premières lignes avec loc
# - **Objectif** : sélectionner des lignes par leur étiquette d'index.
# - **Syntaxe** : `df.loc[debut:fin]` → avec `loc`, la borne de fin est **incluse**.

# %%
df.loc[0:4]
# Out:
#   id_mesure           date_heure id_capteur batiment  temperature  humidite  \
# 0     M0413  2026-01-22 04:00:00       C005     B002        25.46     58.06
# 1     M0290  2026-01-17 01:00:00       C002     B001        24.00     79.73
# 2     M0077  2026-01-08 04:00:00       C005     B002        25.82     54.47
# 3     M0079  2026-01-08 06:00:00       C007     B003        28.23     69.39
# 4     M0183  2026-01-12 14:00:00       C003     B001        20.58     53.80
#
#    pression  consommation etat
# 0   1008.95        287.28   OK
# 1    993.39        116.20   OK
# 2   1010.32        288.50   OK
# 3   1019.62        136.65   OK
# 4   1016.58        182.62   OK

# %% [markdown]
# ### 4. Les 5 premières lignes et 4 premières colonnes avec iloc
# - **Objectif** : sélectionner par **position** (numéros), lignes ET colonnes.
# - **Syntaxe** : `df.iloc[lignes, colonnes]` → avec `iloc`, la borne de fin est **exclue**.

# %%
df.iloc[0:5, 0:4]
# Out:
#   id_mesure           date_heure id_capteur batiment
# 0     M0413  2026-01-22 04:00:00       C005     B002
# 1     M0290  2026-01-17 01:00:00       C002     B001
# 2     M0077  2026-01-08 04:00:00       C005     B002
# 3     M0079  2026-01-08 06:00:00       C007     B003
# 4     M0183  2026-01-12 14:00:00       C003     B001

# %% [markdown]
# ## Partie 5 – Manipulation des colonnes
#
# On peut créer de nouvelles colonnes, les catégoriser, les renommer ou les
# supprimer. Ces opérations préparent les données pour l'analyse.

# %% [markdown]
# ### 1. Ajouter la colonne "temperature_fahrenheit"
# - **Objectif** : créer une colonne calculée à partir d'une autre.
# - **Syntaxe** : `df["nouvelle"] = <calcul sur une colonne existante>`
# - **Formule** : °F = °C × 9/5 + 32

# %%
df["temperature_fahrenheit"] = df["temperature"] * 9/5 + 32
df[["temperature", "temperature_fahrenheit"]].head()
# Out:
#    temperature  temperature_fahrenheit
# 0        25.46                  77.828
# 1        24.00                  75.200
# 2        25.82                  78.476
# 3        28.23                  82.814
# 4        20.58                  69.044

# %% [markdown]
# ### 2. Ajouter la colonne "niveau_temperature"
# - **Objectif** : catégoriser chaque ligne selon une condition.
# - **Syntaxe** : `np.where(condition, valeur_si_vrai, valeur_si_faux)`
#   → il faut importer numpy : `import numpy as np`.

# %%
import numpy as np

df["niveau_temperature"] = np.where(df["temperature"] > 30, "Élevée", "Normale")
df["niveau_temperature"].value_counts()
# Out:
# niveau_temperature
# Normale    559
# Élevée      46
# Name: count, dtype: int64

# %% [markdown]
# ### 3. Renommer "humidite" en "humidite_relative"
# - **Objectif** : changer le nom d'une colonne.
# - **Syntaxe** : `df.rename(columns={"ancien": "nouveau"})`
#   → on réassigne le résultat à `df` pour que le changement soit conservé.

# %%
df = df.rename(columns={"humidite": "humidite_relative"})
df.columns
# Out:
# Index(['id_mesure', 'date_heure', 'id_capteur', 'batiment', 'temperature',
#        'humidite_relative', 'pression', 'consommation', 'etat',
#        'temperature_fahrenheit', 'niveau_temperature'],
#       dtype='str')

# %% [markdown]
# ### 4. Supprimer la colonne "temperature_fahrenheit"
# - **Objectif** : retirer une colonne devenue inutile.
# - **Syntaxe** : `df.drop(columns=["nom_colonne"])`

# %%
df = df.drop(columns=["temperature_fahrenheit"])
df.columns
# Out:
# Index(['id_mesure', 'date_heure', 'id_capteur', 'batiment', 'temperature',
#        'humidite_relative', 'pression', 'consommation', 'etat',
#        'niveau_temperature'],
#       dtype='str')

# %% [markdown]
# ## Partie 6 – Filtrage
#
# Le filtrage garde uniquement les lignes qui respectent une condition. On écrit
# une condition entre crochets ; pour combiner deux conditions, on utilise
# `&` (ET) et `|` (OU), chaque condition entre parenthèses.

# %% [markdown]
# ### 1. Lignes où température > 30
# - **Objectif** : filtrer selon une seule condition.
# - **Syntaxe** : `df[df["colonne"] > valeur]`

# %%
df[df["temperature"] > 30]
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  \
# 7       M0132  2026-01-10 11:00:00       C012     B004        31.21
# 43      M0575  2026-01-28 22:00:00       C011     B004        34.72
# 47      M0082  2026-01-08 09:00:00       C010     B004        32.46
# 63      M0064  2026-01-07 15:00:00       C004     B002        31.19
# 79      M0275  2026-01-16 10:00:00       C011     B004        31.74
# 88      M0288  2026-01-16 23:00:00       C012     B004        30.06
# 103     M0311  2026-01-17 22:00:00       C011     B004        30.83
# 112     M0149  2026-01-11 04:00:00       C005     B002        31.46
# 118     M0365  2026-01-20 04:00:00       C005     B002        32.90
# 129     M0592  2026-01-29 15:00:00       C004     B002        33.60
# 137     M0076  2026-01-08 03:00:00       C004     B002        31.18
# 145     M0503  2026-01-25 22:00:00       C011     B004        30.57
# 146     M0118  2026-01-09 21:00:00       C010     B004        30.32
# ...

# %% [markdown]
# ### 2. Lignes où température > 30 ET humidité > 70
# - **Objectif** : combiner deux conditions.
# - **Syntaxe** : `df[(condition1) & (condition2)]`

# %%
df[(df["temperature"] > 30) & (df["humidite_relative"] > 70)]
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  \
# 47      M0082  2026-01-08 09:00:00       C010     B004        32.46
# 88      M0288  2026-01-16 23:00:00       C012     B004        30.06
# 129     M0592  2026-01-29 15:00:00       C004     B002        33.60
# 145     M0503  2026-01-25 22:00:00       C011     B004        30.57
# 165     M0323  2026-01-18 10:00:00       C011     B004        33.01
# 168     M0276  2026-01-16 11:00:00       C012     B004        30.39
# 210     M0588  2026-01-29 11:00:00       C012     B004        31.51
# 251     M0114  2026-01-09 17:00:00       C006     B002        31.85
# 264     M0191  2026-01-12 22:00:00       C011     B004        30.75
# 280     M0585  2026-01-29 08:00:00       C009     B003        31.30
# 385     M0126  2026-01-10 05:00:00       C006     B002        30.09
# 398     M0514  2026-01-26 09:00:00       C010     B004        30.48
# 502     M0048  2026-01-06 23:00:00       C012     B004        58.70
# ...

# %% [markdown]
# ## Partie 7 – Tri
#
# Trier réorganise les lignes selon les valeurs d'une ou plusieurs colonnes,
# en ordre croissant ou décroissant.

# %% [markdown]
# ### 1 à 3. Trier par température
# - **Objectif** : ordonner les lignes selon la température.
# - **Syntaxe** : `df.sort_values(by="colonne", ascending=True/False)`
#   (`ascending=True` = croissant, valeur par défaut ; `False` = décroissant.)

# %%
df_trie1 = df.sort_values(by="temperature")                     # croissant
df_trie2 = df.sort_values(by="temperature", ascending=False)    # décroissant
top10 = df.sort_values(by="temperature", ascending=False).head(10)  # 10 plus élevées
top10
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  \
# 502     M0048  2026-01-06 23:00:00       C012     B004        58.70
# 43      M0575  2026-01-28 22:00:00       C011     B004        34.72
# 129     M0592  2026-01-29 15:00:00       C004     B002        33.60
# 211     M0370  2026-01-20 09:00:00       C010     B004        33.29
# 165     M0323  2026-01-18 10:00:00       C011     B004        33.01
# 118     M0365  2026-01-20 04:00:00       C005     B002        32.90
# 520     M0063  2026-01-07 14:00:00       C003     B001        32.72
# 438     M0558  2026-01-28 05:00:00       C006     B002        32.56
# 47      M0082  2026-01-08 09:00:00       C010     B004        32.46
# 169     M0546  2026-01-27 17:00:00       C006     B002        32.36
#
#      humidite_relative  pression  consommation    etat niveau_temperature
# 502              81.51   1026.79        271.92  ERREUR             Élevée
# ...

# %% [markdown]
# ### 4. Trier par bâtiment (croissant) puis température (décroissant)
# - **Objectif** : trier sur plusieurs colonnes avec des ordres différents.
# - **Syntaxe** : `df.sort_values(by=["col1","col2"], ascending=[True, False])`

# %%
df.sort_values(by=["batiment", "temperature"], ascending=[True, False])
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  \
# 520     M0063  2026-01-07 14:00:00       C003     B001        32.72
# 447     M0170  2026-01-12 01:00:00       C002     B001        31.15
# 224     M0303  2026-01-17 14:00:00       C003     B001        30.84
# 500     M0062  2026-01-07 13:00:00       C002     B001        30.39
# 9       M0087  2026-01-08 14:00:00       C003     B001        28.85
# ..        ...                  ...        ...      ...          ...
# 277     M0383  2026-01-20 22:00:00       C011     B004        20.60
# 338     M0060  2026-01-07 11:00:00       C012     B004        20.56
# 487     M0538  2026-01-27 09:00:00       C010     B004       -18.50
# 215     M0204  2026-01-13 11:00:00       C012     B004          NaN
# 513     M0490  2026-01-25 09:00:00       C010     B004          NaN
#
#      humidite_relative  pression  consommation    etat niveau_temperature
# 520              53.28   1010.05        195.37  ALERTE             Élevée
# ...

# %% [markdown]
# ## Partie 8 – Analyse
#
# On regroupe les données par catégorie (ici, par bâtiment) pour calculer des
# statistiques par groupe. L'outil central est `groupby`.

# %%
df.groupby("batiment")["consommation"].mean()
# Out:
# batiment
# B001    177.870927
# B002    221.785333
# B003    153.191000
# B004    282.552282
# Name: consommation, dtype: float64

# %% [markdown]
# ### 2. Min, max, moyenne, écart-type de la température par bâtiment
# - **Objectif** : plusieurs stats d'un coup sur une colonne groupée.
# - **Syntaxe** : `df.groupby("cat")["col"].agg(["min","max","mean","std"])`

# %%
df.groupby("batiment")["temperature"].agg(["min", "max", "mean", "std"])
# Out:
#             min    max       mean       std
# batiment
# B001      16.77  32.72  23.578824  2.961211
# B002      17.67  33.60  25.778000  2.951828
# B003      14.11  31.74  23.013699  2.983902
# B004     -18.50  58.70  27.119000  5.367361

# %% [markdown]
# ### 3. Max et moyenne de température ET consommation, par bâtiment
# - **Objectif** : stats différentes sur plusieurs colonnes.
# - **Syntaxe** : `df.groupby("cat").agg({"col1": [...], "col2": [...]})`

# %%
df.groupby("batiment").agg({
    "temperature": ["max", "mean"],
    "consommation": ["max", "mean"]
})
# Out:
#          temperature            consommation
#                  max       mean          max        mean
# batiment
# B001           32.72  23.578824       294.72  177.870927
# B002           33.60  25.778000       335.20  221.785333
# B003           31.74  23.013699       875.00  153.191000
# B004           58.70  27.119000       411.12  282.552282

# %% [markdown]
# ### 4 à 6. Statistiques globales
# - **Objectif** : quelques agrégats sur l'ensemble du tableau.
# - **Syntaxe** : `df["col"].mean()`, `.max()`, `.sum()`

# %%
print("Température moyenne globale :", df["temperature"].mean())
print("Température maximale :", df["temperature"].max())
print("Consommation totale :", df["consommation"].sum())
# Out:
# Température moyenne globale : 24.87831385642738
# Température maximale : 58.7
# Consommation totale : 125205.25

# %% [markdown]
# ### 7. Quel bâtiment consomme le plus en moyenne ?
# - **Objectif** : trouver la catégorie ayant la plus grande valeur.
# - **Syntaxe** : `.idxmax()` renvoie l'étiquette du maximum.

# %%
conso_moyenne = df.groupby("batiment")["consommation"].mean()
print("Bâtiment le plus consommateur :", conso_moyenne.idxmax())
# Out:
# Bâtiment le plus consommateur : B004

# %% [markdown]
# ### 8. Nombre d'alertes par bâtiment
# - **Objectif** : compter les lignes en état "ALERTE" pour chaque bâtiment.
# - **Syntaxe** : on filtre d'abord (`etat == "ALERTE"`), puis on groupe et on compte
#   avec `.size()`

# %%
df[df["etat"] == "ALERTE"].groupby("batiment").size()
# Out:
# batiment
# B001     2
# B002     7
# B003     5
# B004    15
# dtype: int64

# %% [markdown]
# ## Partie 9 – Gestion des valeurs manquantes
#
# Les valeurs manquantes (NaN) faussent les analyses. On les repère puis on les
# remplace par une valeur raisonnable (moyenne, médiane, ou une étiquette).

# %% [markdown]
# ### 1 à 4. Repérer les valeurs manquantes
# - **Objectif** : compter et localiser les NaN.
# - **Syntaxe** :
#   - `df.isnull().sum()` → nombre de NaN par colonne
#   - `df.isnull().sum().sum()` → total de NaN
#   - `df.isnull().mean() * 100` → taux (%) par colonne
#   - `df[df.isnull().any(axis=1)]` → les lignes contenant au moins un NaN

# %%
print("NaN par colonne :")
print(df.isnull().sum())

print("\nTotal de NaN :", df.isnull().sum().sum())

print("\nTaux de NaN (%) :")
print((df.isnull().mean() * 100).round(2))

print("\nLignes contenant des NaN :")
display(df[df.isnull().any(axis=1)])
# Out:
# NaN par colonne :
# id_mesure             0
# date_heure            0
# id_capteur            0
# batiment              0
# temperature           6
# humidite_relative     5
# pression              5
# consommation          5
# etat                  4
# niveau_temperature    0
# dtype: int64
#
# Total de NaN : 25
#
# Taux de NaN (%) :
# id_mesure             0.00
# date_heure            0.00
# id_capteur            0.00
# batiment              0.00
# temperature           0.99
# humidite_relative     0.83
# pression              0.83
# consommation          0.83
# etat                  0.66
# niveau_temperature    0.00
# dtype: float64
#
# Lignes contenant des NaN :
#     id_mesure           date_heure id_capteur batiment  temperature  \
# 14      M0056  2026-01-07 07:00:00       C008     B003        22.33
# 30      M0073  2026-01-08 00:00:00       C001     B001        23.12
# 91      M0473  2026-01-24 16:00:00       C005     B002        21.32
# ...

# %% [markdown]
# ### 5 à 7. Remplacer les valeurs manquantes
# - **Objectif** : combler les NaN selon la colonne.
# - **Syntaxe** : `df["col"].fillna(valeur)`
#   - température & humidité → la **moyenne** (`.mean()`)
#   - consommation → la **médiane** (`.median()`)
#   - etat → l'étiquette **"INCONNU"**

# %%
df["temperature"] = df["temperature"].fillna(df["temperature"].mean())
df["humidite_relative"] = df["humidite_relative"].fillna(df["humidite_relative"].mean())
df["consommation"] = df["consommation"].fillna(df["consommation"].median())
df["etat"] = df["etat"].fillna("INCONNU")

# Vérification
df.isnull().sum()
